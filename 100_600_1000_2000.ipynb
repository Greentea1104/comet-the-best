# %%
import pandas as pd 

df_train = pd.read_csv('train_data.csv')
df_valid = pd.read_csv('valid_data.csv')
df_test = pd.read_csv('test_data.csv')

# %%
# x_train, y_train 설정
x_train = pd.concat([df_train.iloc[:, 16:67], df_train.iloc[:, 106:207]], axis=1)
y_train = df_train.iloc[:, 5]

# x_valid, y_valid 설정
x_valid = pd.concat([df_valid.iloc[:, 16:67], df_valid.iloc[:, 106:207]], axis=1)
y_valid = df_valid.iloc[:, 5]

# x_test, y_test 설정
x_test = pd.concat([df_test.iloc[:, 16:67], df_test.iloc[:, 106:207]], axis=1)
y_test = df_test.iloc[:, 5]

# %%
print(x_train.shape)
print(y_train.shape)

print(x_valid.shape)
print(y_valid.shape)

print(x_test.shape)
print(y_test.shape)
# Out:
# (50051, 152)
# (50051,)
# (12513, 152)
# (12513,)
# (7820, 152)
# (7820,)

# %%
# 필요 라이브러리 불러오기 
import numpy as np
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
from sklearn.preprocessing import LabelEncoder
import xgboost as xgb

# %%
from sklearn.preprocessing import LabelEncoder

# Encode target labels with value between 0 and n_classes-1
# XGBClassifier를 사용하기 위해 대상 레이블을 정수로 인코딩해야 합니다.
# 현재 대상 레이블은 범주형 문자열이므로, LabelEncoder를 사용하여 숫자로 변환해야 합니다.

label_encoder = LabelEncoder()
y_train = label_encoder.fit_transform(y_train)
y_valid = label_encoder.transform(y_valid)
y_test = label_encoder.transform(y_test)

# got ['in' 'noise' 'normal' 'other' 'out']---> 클래스를 정수로 인코딩: [0 1 2 3 4]

# %%
pip install xgboost
# Out:
# Requirement already satisfied: xgboost in c:\users\dahee\anaconda3\lib\site-packages (2.0.3)
# Requirement already satisfied: numpy in c:\users\dahee\anaconda3\lib\site-packages (from xgboost) (1.24.3)
# Requirement already satisfied: scipy in c:\users\dahee\anaconda3\lib\site-packages (from xgboost) (1.10.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.metrics import accuracy_score

# DMatrix 객체 생성
dtrain = xgb.DMatrix(data=x_train, label=y_train)
dvalid = xgb.DMatrix(data=x_valid, label=y_valid)
dtest = xgb.DMatrix(data=x_test, label=y_test)

# 파라미터 설정 (손실함수와 클래스 개수 지정하는 파라미터)
params = {
    'objective': 'multi:softprob',
    'num_class': 5,  
}

# %%
# 학습
num_round = 100
watchlist = [(dtrain, 'train'), (dvalid, 'valid')]
model = xgb.train(params, dtrain, num_round, watchlist, early_stopping_rounds=10)

# Early stopping은 모델의 과적합을 방지하고 최적의 모델을 얻기 위해 매우 유용한 기법을 사용하였음
# Out:
# [0]	train-mlogloss:1.37256	valid-mlogloss:1.38269
# C:\Users\dahee\anaconda3\Lib\site-packages\xgboost\core.py:727: FutureWarning: Pass `evals` as keyword args.
#   warnings.warn(msg, FutureWarning)
# [1]	train-mlogloss:1.22795	valid-mlogloss:1.24739
# [2]	train-mlogloss:1.12286	valid-mlogloss:1.15001
# [3]	train-mlogloss:1.04468	valid-mlogloss:1.07900
# [4]	train-mlogloss:0.98488	valid-mlogloss:1.02424
# [5]	train-mlogloss:0.93438	valid-mlogloss:0.97831
# [6]	train-mlogloss:0.89060	valid-mlogloss:0.93836
# [7]	train-mlogloss:0.85304	valid-mlogloss:0.90411
# [8]	train-mlogloss:0.82122	valid-mlogloss:0.87590
# [9]	train-mlogloss:0.79431	valid-mlogloss:0.85215
# [10]	train-mlogloss:0.77152	valid-mlogloss:0.83268
# [11]	train-mlogloss:0.74751	valid-mlogloss:0.80986
# [12]	train-mlogloss:0.72473	valid-mlogloss:0.79098
# [13]	train-mlogloss:0.70887	valid-mlogloss:0.77696
# [14]	train-mlogloss:0.69119	valid-mlogloss:0.76162
# [15]	train-mlogloss:0.67597	valid-mlogloss:0.74858
# [16]	train-mlogloss:0.66088	valid-mlogloss:0.73495
# [17]	train-mlogloss:0.64983	valid-mlogloss:0.72497
# [18]	train-mlogloss:0.63832	valid-mlogloss:0.71514
# [19]	train-mlogloss:0.62851	valid-mlogloss:0.70656
# [20]	train-mlogloss:0.61836	valid-mlogloss:0.69798
# [21]	train-mlogloss:0.61039	valid-mlogloss:0.69096
# [22]	train-mlogloss:0.60173	valid-mlogloss:0.68397
# [23]	train-mlogloss:0.59252	valid-mlogloss:0.67621
# [24]	train-mlogloss:0.58149	valid-mlogloss:0.66700
# [25]	train-mlogloss:0.57338	valid-mlogloss:0.65955
# [26]	train-mlogloss:0.56569	valid-mlogloss:0.65307
# [27]	train-mlogloss:0.55775	valid-mlogloss:0.64618
# [28]	train-mlogloss:0.55331	valid-mlogloss:0.64235
# [29]	train-mlogloss:0.54642	valid-mlogloss:0.63606
# [30]	train-mlogloss:0.54076	valid-mlogloss:0.63127
# [31]	train-mlogloss:0.53065	valid-mlogloss:0.62327
# [32]	train-mlogloss:0.52253	valid-mlogloss:0.61720
# [33]	train-mlogloss:0.51740	valid-mlogloss:0.61300
# [34]	train-mlogloss:0.51259	valid-mlogloss:0.60904
# [35]	train-mlogloss:0.50758	valid-mlogloss:0.60498
# [36]	train-mlogloss:0.50107	valid-mlogloss:0.59924
# [37]	train-mlogloss:0.49550	valid-mlogloss:0.59443
# [38]	train-mlogloss:0.49194	valid-mlogloss:0.59154
# [39]	train-mlogloss:0.48467	valid-mlogloss:0.58560
# [40]	train-mlogloss:0.47753	valid-mlogloss:0.58041
# [41]	train-mlogloss:0.47298	valid-mlogloss:0.57662
# [42]	train-mlogloss:0.46809	valid-mlogloss:0.57277
# [43]	train-mlogloss:0.46185	valid-mlogloss:0.56817
# [44]	train-mlogloss:0.45787	valid-mlogloss:0.56462
# [45]	train-mlogloss:0.45213	valid-mlogloss:0.55987
# [46]	train-mlogloss:0.44610	valid-mlogloss:0.55477
# [47]	train-mlogloss:0.44190	valid-mlogloss:0.55160
# [48]	train-mlogloss:0.43654	valid-mlogloss:0.54729
# [49]	train-mlogloss:0.43250	valid-mlogloss:0.54393
# [50]	train-mlogloss:0.42645	valid-mlogloss:0.53931
# [51]	train-mlogloss:0.42158	valid-mlogloss:0.53500
# [52]	train-mlogloss:0.41608	valid-mlogloss:0.53073
# [53]	train-mlogloss:0.41239	valid-mlogloss:0.52746
# [54]	train-mlogloss:0.40922	valid-mlogloss:0.52452
# [55]	train-mlogloss:0.40551	valid-mlogloss:0.52142
# [56]	train-mlogloss:0.39879	valid-mlogloss:0.51599
# [57]	train-mlogloss:0.39256	valid-mlogloss:0.51113
# [58]	train-mlogloss:0.38865	valid-mlogloss:0.50792
# [59]	train-mlogloss:0.38561	valid-mlogloss:0.50532
# [60]	train-mlogloss:0.38082	valid-mlogloss:0.50171
# [61]	train-mlogloss:0.37784	valid-mlogloss:0.49953
# [62]	train-mlogloss:0.37386	valid-mlogloss:0.49618
# [63]	train-mlogloss:0.36944	valid-mlogloss:0.49257
# [64]	train-mlogloss:0.36534	valid-mlogloss:0.48955
# [65]	train-mlogloss:0.36288	valid-mlogloss:0.48776
# [66]	train-mlogloss:0.35930	valid-mlogloss:0.48445
# [67]	train-mlogloss:0.35619	valid-mlogloss:0.48184
# [68]	train-mlogloss:0.35191	valid-mlogloss:0.47848
# [69]	train-mlogloss:0.34707	valid-mlogloss:0.47444
# [70]	train-mlogloss:0.34344	valid-mlogloss:0.47141
# [71]	train-mlogloss:0.33969	valid-mlogloss:0.46835
# [72]	train-mlogloss:0.33675	valid-mlogloss:0.46610
# [73]	train-mlogloss:0.33418	valid-mlogloss:0.46401
# [74]	train-mlogloss:0.33106	valid-mlogloss:0.46133
# [75]	train-mlogloss:0.32822	valid-mlogloss:0.45919
# [76]	train-mlogloss:0.32573	valid-mlogloss:0.45718
# [77]	train-mlogloss:0.32183	valid-mlogloss:0.45453
# [78]	train-mlogloss:0.31982	valid-mlogloss:0.45310
# [79]	train-mlogloss:0.31631	valid-mlogloss:0.45055
# [80]	train-mlogloss:0.31331	valid-mlogloss:0.44802
# [81]	train-mlogloss:0.31074	valid-mlogloss:0.44589
# [82]	train-mlogloss:0.30563	valid-mlogloss:0.44160
# [83]	train-mlogloss:0.30205	valid-mlogloss:0.43860
# [84]	train-mlogloss:0.29951	valid-mlogloss:0.43655
# [85]	train-mlogloss:0.29629	valid-mlogloss:0.43426
# [86]	train-mlogloss:0.29339	valid-mlogloss:0.43184
# [87]	train-mlogloss:0.29043	valid-mlogloss:0.42937
# [88]	train-mlogloss:0.28693	valid-mlogloss:0.42701
# [89]	train-mlogloss:0.28294	valid-mlogloss:0.42368
# [90]	train-mlogloss:0.27977	valid-mlogloss:0.42128
# [91]	train-mlogloss:0.27695	valid-mlogloss:0.41896
# [92]	train-mlogloss:0.27498	valid-mlogloss:0.41742
# [93]	train-mlogloss:0.27284	valid-mlogloss:0.41556
# [94]	train-mlogloss:0.27015	valid-mlogloss:0.41397
# [95]	train-mlogloss:0.26748	valid-mlogloss:0.41193
# [96]	train-mlogloss:0.26507	valid-mlogloss:0.41014
# [97]	train-mlogloss:0.26235	valid-mlogloss:0.40826
# [98]	train-mlogloss:0.25933	valid-mlogloss:0.40596
# [99]	train-mlogloss:0.25725	valid-mlogloss:0.40456

# %%
# 예측
pred_probs = model.predict(dtest)
preds = np.asarray([np.argmax(line) for line in pred_probs])

# %%
# 정확도 계산
accuracy = accuracy_score(y_test, preds)
print(f"Accuracy: {accuracy * 100:.2f}%")
# Out:
# Accuracy: 87.02%

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score, auc, roc_curve


# 성능 평가 함수 정의
def get_clf_eval(y_true, y_pred):
    confusion = confusion_matrix(y_true, y_pred)
    accuracy = accuracy_score(y_true, y_pred)
    precision = precision_score(y_true, y_pred, average='weighted')
    recall = recall_score(y_true, y_pred, average='weighted')
    f1 = f1_score(y_true, y_pred, average='weighted')

    print("Confusion Matrix:")
    print(confusion)
    print(f"Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-score: {f1:.4f}")

# 학습 데이터와 테스트 데이터 예측
y_pred_train_probs = bst.predict(dtrain)
y_pred_test_probs = bst.predict(dtest)

# 예측 확률을 클래스 레이블로 변환
y_pred_train = np.argmax(y_pred_train_probs, axis=1)
y_pred_test = np.argmax(y_pred_test_probs, axis=1)

# 학습 데이터 평가
print("Training Data Evaluation:")
get_clf_eval(y_train, y_pred_train)

# 테스트 데이터 평가
print("\nTest Data Evaluation:")
get_clf_eval(y_test, y_pred_test)
# Out:
# Training Data Evaluation:
# Confusion Matrix:
# [[ 9787    58   268    71   373]
#  [   80  3706   139    48    82]
#  [   18     9 15773     6    18]
#  [  154    51   135  5116   171]
#  [  206    65   254    76 13387]]
# Accuracy: 0.9544, Precision: 0.9545, Recall: 0.9544, F1-score: 0.9541
#
# Test Data Evaluation:
# Confusion Matrix:
# [[1378   35   77   26  143]
#  [  59  457   35   22   56]
#  [  23   10 2389   14   26]
#  [  66   24   51  633  104]
#  [ 124   24   70   26 1948]]
# Accuracy: 0.8702, Precision: 0.8692, Recall: 0.8702, F1-score: 0.8682

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools 

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# 예시 혼동 행렬 데이터
confusion_matrix_data = np.array([[9787, 58, 268, 71, 373],
                                  [80, 3706, 139, 48, 82],
                                  [18, 9, 15773, 6, 18],
                                  [154, 51, 135, 5116, 171],
                                  [206, 65, 254, 76, 13387]])

# 클래스 레이블
classes = ['Class 0', 'Class 1', 'Class 2', 'Class 3', 'Class 4']

# 혼동 행렬 출력 (정규화하지 않음)
plt.figure()
plot_confusion_matrix(confusion_matrix_data, classes=classes,
                      title='Confusion Matrix - Train')

# 혼동 행렬 출력 (정규화)
plt.figure()
plot_confusion_matrix(confusion_matrix_data, classes=classes, normalize=True,
                      title='Confusion Matrix - Train; Normalized')

plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %%
import matplotlib.pyplot as plt
import numpy as np
import itertools 

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# 예시 혼동 행렬 데이터
confusion_matrix_data = np.array([[9787, 58, 268, 71, 373],
                                  [80, 3706, 139, 48, 82],
                                  [18, 9, 15773, 6, 18],
                                  [154, 51, 135, 5116, 171],
                                  [206, 65, 254, 76, 13387]])

# 클래스 레이블
classes = ['Class 0', 'Class 1', 'Class 2', 'Class 3', 'Class 4']

# 혼동 행렬 출력 (정규화하지 않음)
plt.figure()
plot_confusion_matrix(confusion_matrix_data, classes=classes,
                      title='Confusion Matrix - Train')

# 혼동 행렬 출력 (정규화)
plt.figure()
plot_confusion_matrix(confusion_matrix_data, classes=classes, normalize=True,
                      title='Confusion Matrix - Train; Normalized')

plt.show()
# Out:
# Confusion matrix, without normalization
# Normalized confusion matrix

# %%
# ROC curve 및 AUC 계산 함수
def plot_roc_curve_multi(y_true, y_pred_probs, num_classes):
    plt.figure(figsize=(10, 8))
    for i in range(num_classes):
        fpr, tpr, thresholds = roc_curve(y_true == i, y_pred_probs[:, i])
        roc_auc = auc(fpr, tpr)
        plt.plot(fpr, tpr, lw=2, label=f'Class {i} (area = {roc_auc:.2f})')
    plt.plot([0, 1], [0, 1], color='navy', lw=2, linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('Receiver Operating Characteristic - Multi-class')
    plt.legend(loc="lower right")
    plt.show()

    
# ROC curve 및 AUC 계산 및 그리기
plot_roc_curve_multi(y_test, y_pred_test_probs, 5)
